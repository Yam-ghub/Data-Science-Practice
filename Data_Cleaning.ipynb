# %% [markdown]
# <a href="https://colab.research.google.com/github/Yam-ghub/Data-Science-Practice/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print(pd.__version__)
# Out:
#   File "<ipython-input-48-e616a1e4d356>", line 3
#     pip install --upgrade pandas
#         ^
# SyntaxError: invalid syntax

# %%
pip install --upgrade pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 118.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel("/content/Customer_Call _List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.drop_duplicates()
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Last_Name'].str.strip("123./")
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# 20      Skywalker
# Name: Last_Name, dtype: object

# %% [markdown]
# - It cleans the uncessary characters in the data.

# %%
#This will replace the other values to numeric values only by turning unwanted character into a blank
#using replace
df["Phone_Number"].str.replace('[^a-zA-Z0-9]',' ')

#note: transform the values and it should have the same data type. str, float, etc.
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))

#
df["Phone_Number"].apply(lambda x: x[0:3]+ '-' + x[3:6] + '-' + x[6:10])
# Out:
# 0     123--54-5-54
# 1     123-/64-3/97
# 2     706-695-0392
# 3     123--54-3-23
# 4     876-|67-8|34
# 5     304--76-2-24
# 6            nan--
# 7     876-|67-8|34
# 8            N/a--
# 9     123--54-5-54
# 10           nan--
# 11    706-695-0392
# 12    123--54-3-23
# 13    876-|67-8|34
# 14    304--76-2-24
# 15    123--54-5-54
# 16    123-/64-3/97
# 17    706-695-0392
# 18           N/a--
# 19    876-|67-8|34
# 20    876-|67-8|34
# Name: Phone_Number, dtype: object

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace('nan--',' ')
df["Phone_Number"] = df["Phone_Number"].str.strip("nan")
df["Phone_Number"] = df["Phone_Number"].str.strip("N/a")
df["Phone_Number"] = df["Phone_Number"].str.strip()
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))
df["Phone_Number"].str.replace('[^a-zA-Z0-9]',' ')
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3]+ '-' + x[3:6] + '-' + x[6:10])
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  ------------
# 1         1002       Abed        Nadir  ------------
# 2         1003     Walter        White  ------------
# 3         1004     Dwight      Schrute  ------------
# 4         1005        Jon         Snow  ------------
# 5         1006        Ron      Swanson  ------------
# 6         1007       Jeff       Winger            --
# 7         1008   Sherlock       Holmes  ------------
# 8         1009    Gandalf          NaN            --
# 9         1010      Peter       Parker  ------------
# 10        1011    Samwise       Gamgee            --
# 11        1012      Harry       Potter  ------------
# 12        1013        Don       Draper  ------------
# 13        1014     Leslie        Knope  ------------
# 14        1015       Toby  Flenderson_  ------------
# 15        1016        Ron      Weasley  ------------
# 16        1017   Michael         Scott  ------------
# ...

# %%
df['Address'].str.split(pat=None, n=-1, expand=False)
# Out:
# 0                      [123, Shire, Lane,, Shire]
# 1                        [93, West, Main, Street]
# 2                          [298, Drugs, Driveway]
# 3     [980, Paper, Avenue,, Pennsylvania,, 18503]
# 4                            [123, Dragons, Road]
# 5                            [768, City, Parkway]
# 6                           [1209, South, Street]
# 7                               [98, Clue, Drive]
# 8                            [123, Middle, Earth]
# 9                [25th, Main, Street,, New, York]
# 10                     [612, Shire, Lane,, Shire]
# 11                       [2394, Hogwarts, Avenue]
# 12                           [2039, Main, Street]
# 13                           [343, City, Parkway]
# 14                              [214, HR, Avenue]
# 15                       [2395, Hogwarts, Avenue]
# 16            [121, Paper, Avenue,, Pennsylvania]
# 17                            [3498, Super, Lane]
# 18                                          [N/a]
# ...

# %%
df["Paying Customer"].apply(lambda x: str(x))
df["Paying Customer"] = df["Paying Customer"].str.replace('Y', 'Yes')
df["Paying Customer"] = df["Paying Customer"].str.replace('Noooo', 'No')
df["Paying Customer"]
# Out:
# 0      Yes
# 1       No
# 2       No
# 3      Yes
# 4      Yes
# 5      Yes
# 6       No
# 7       No
# 8      Yes
# 9      Yes
# 10     Yes
# 11     Yes
# 12     Yes
# 13     Yes
# 14      No
# 15      No
# 16     Yes
# 17     Yes
# 18    No/a
# 19     Yes
# 20     Yes
# Name: Paying Customer, dtype: object

# %%
df.fillna('')
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter        White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry       Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].fillna('')
df["Do_Not_Contact"]
df["Do_Not_Contact"] = df["Do_Not_Contact"].
# Out:
# 0     No
# 2
# 4     No
# 6     No
# 7     No
# 8
# 9     No
# 10    No
# 11
# 12     N
# 13    No
# 14    No
# 15     N
# 16    No
# 17
# 19     N
# 20     N
# Name: Do_Not_Contact, dtype: object

# %%
for x in df.index:
  if df.loc[x, "Do_Not_Contact"] == ' ';
    df.drop(x, inplace=True)

df["Do_Not_Contact"]
# Out:
# 0     No
# 2
# 4     No
# 6     No
# 7     No
# 8
# 9     No
# 10    No
# 11
# 12     N
# 13    No
# 14    No
# 15     N
# 16    No
# 17
# 19     N
# 20     N
# Name: Do_Not_Contact, dtype: object

# %%
df = df.reset_index(drop=True)
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  ------------
# 1         1003     Walter        White  ------------
# 2         1005        Jon         Snow  ------------
# 3         1007       Jeff       Winger            --
# 4         1008   Sherlock       Holmes  ------------
# 5         1009    Gandalf          NaN            --
# 6         1010      Peter       Parker  ------------
# 7         1011    Samwise       Gamgee            --
# 8         1012      Harry       Potter  ------------
# 9         1013        Don       Draper  ------------
# 10        1014     Leslie        Knope  ------------
# 11        1015       Toby  Flenderson_  ------------
# 12        1016        Ron      Weasley  ------------
# 13        1017   Michael         Scott  ------------
# 14        1018      Clark         Kent  ------------
# 15        1020     Anakin    Skywalker  ------------
# 16        1020     Anakin    Skywalker  ------------
#
# ...
